# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('penguins.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap ='gray', interpolation='bicubic')#showing the image

plt.plot([600,200], [200,300],'r', linewidth=5)#drawing a red line on the image
plt.show()
